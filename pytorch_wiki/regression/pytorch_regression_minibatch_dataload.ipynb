# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
from torch.utils.data import TensorDataset # 텐서데이터셋
from torch.utils.data import DataLoader # 데이터로더

# %%
x_train  =  torch.FloatTensor([[73,  80,  75], 
                               [93,  88,  93], 
                               [89,  91,  90], 
                               [96,  98,  100],   
                               [73,  66,  70]])  
y_train  =  torch.FloatTensor([[152],  [185],  [180],  [196],  [142]])

# %%
dataset = TensorDataset(x_train, y_train)

# %%
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

# %%
model = nn.Linear(3,1)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)

# %%
nb_epochs = 20
for epoch in range(nb_epochs + 1):
  for batch_idx, samples in enumerate(dataloader):
    # print(batch_idx)
    # print(samples)
    x_train, y_train = samples
    # H(x) 계산
    prediction = model(x_train)

    # cost 계산
    cost = F.mse_loss(prediction, y_train)

    # cost로 H(x) 계산
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_idx+1, len(dataloader),
        cost.item()
        ))
# Out:
# Epoch    0/20 Batch 1/3 Cost: 0.538692
# Epoch    0/20 Batch 2/3 Cost: 1.622490
# Epoch    0/20 Batch 3/3 Cost: 0.056807
# Epoch    1/20 Batch 1/3 Cost: 0.394375
# Epoch    1/20 Batch 2/3 Cost: 1.079894
# Epoch    1/20 Batch 3/3 Cost: 0.014264
# Epoch    2/20 Batch 1/3 Cost: 0.242351
# Epoch    2/20 Batch 2/3 Cost: 0.705786
# Epoch    2/20 Batch 3/3 Cost: 1.427641
# Epoch    3/20 Batch 1/3 Cost: 0.656182
# Epoch    3/20 Batch 2/3 Cost: 1.074584
# Epoch    3/20 Batch 3/3 Cost: 0.421461
# Epoch    4/20 Batch 1/3 Cost: 0.420359
# Epoch    4/20 Batch 2/3 Cost: 1.740814
# Epoch    4/20 Batch 3/3 Cost: 0.040636
# Epoch    5/20 Batch 1/3 Cost: 0.801610
# Epoch    5/20 Batch 2/3 Cost: 0.544696
# Epoch    5/20 Batch 3/3 Cost: 1.140283
# Epoch    6/20 Batch 1/3 Cost: 1.688871
# Epoch    6/20 Batch 2/3 Cost: 0.647314
# Epoch    6/20 Batch 3/3 Cost: 0.161598
# Epoch    7/20 Batch 1/3 Cost: 1.110694
# Epoch    7/20 Batch 2/3 Cost: 0.389964
# Epoch    7/20 Batch 3/3 Cost: 1.107511
# Epoch    8/20 Batch 1/3 Cost: 1.330091
# Epoch    8/20 Batch 2/3 Cost: 0.352000
# Epoch    8/20 Batch 3/3 Cost: 0.317919
# Epoch    9/20 Batch 1/3 Cost: 0.298804
# Epoch    9/20 Batch 2/3 Cost: 1.098999
# Epoch    9/20 Batch 3/3 Cost: 0.519039
# Epoch   10/20 Batch 1/3 Cost: 0.175211
# Epoch   10/20 Batch 2/3 Cost: 1.021482
# Epoch   10/20 Batch 3/3 Cost: 1.721375
# Epoch   11/20 Batch 1/3 Cost: 0.567710
# Epoch   11/20 Batch 2/3 Cost: 0.669587
# Epoch   11/20 Batch 3/3 Cost: 2.060795
# Epoch   12/20 Batch 1/3 Cost: 0.435241
# Epoch   12/20 Batch 2/3 Cost: 0.347143
# Epoch   12/20 Batch 3/3 Cost: 2.019907
# Epoch   13/20 Batch 1/3 Cost: 1.298680
# Epoch   13/20 Batch 2/3 Cost: 0.753729
# Epoch   13/20 Batch 3/3 Cost: 0.278204
# Epoch   14/20 Batch 1/3 Cost: 0.510551
# Epoch   14/20 Batch 2/3 Cost: 1.067985
# Epoch   14/20 Batch 3/3 Cost: 0.383656
# Epoch   15/20 Batch 1/3 Cost: 0.898971
# Epoch   15/20 Batch 2/3 Cost: 0.395535
# Epoch   15/20 Batch 3/3 Cost: 1.330113
# Epoch   16/20 Batch 1/3 Cost: 0.647620
# Epoch   16/20 Batch 2/3 Cost: 1.066469
# Epoch   16/20 Batch 3/3 Cost: 0.057164
# Epoch   17/20 Batch 1/3 Cost: 0.683055
# Epoch   17/20 Batch 2/3 Cost: 0.475127
# Epoch   17/20 Batch 3/3 Cost: 1.360482
# Epoch   18/20 Batch 1/3 Cost: 0.657252
# Epoch   18/20 Batch 2/3 Cost: 0.608129
# Epoch   18/20 Batch 3/3 Cost: 2.115832
# Epoch   19/20 Batch 1/3 Cost: 0.296892
# Epoch   19/20 Batch 2/3 Cost: 1.508402
# Epoch   19/20 Batch 3/3 Cost: 0.490851
# Epoch   20/20 Batch 1/3 Cost: 0.106359
# Epoch   20/20 Batch 2/3 Cost: 1.151318
# Epoch   20/20 Batch 3/3 Cost: 1.576225

# %%
new_var =  torch.FloatTensor([[73, 80, 75]]) 
pred_y = model(new_var) 
print("훈련 후 입력이 73, 80, 75일 때의 예측값 :", pred_y)
# Out:
# 훈련 후 입력이 73, 80, 75일 때의 예측값 : tensor([[152.2714]], grad_fn=<AddmmBackward>)
