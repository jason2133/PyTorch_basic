# %%
# !pip3 install torch

# %%
import torch

# %%
mat_a = torch.tensor([0, 3, 5, 5, 5, 2]).view(2, 3)
mat_a
# Out:
# tensor([[0, 3, 5],
#         [5, 5, 2]])

# %%
mat_b = torch.tensor([3, 4, 3, -2, 4, -2]).view(3, 2)
mat_b
# Out:
# tensor([[ 3,  4],
#         [ 3, -2],
#         [ 4, -2]])

# %%
torch.matmul(mat_a, mat_b) # 행렬 곱셈
# Out:
# tensor([[ 29, -16],
#         [ 38,   6]])

# %%
mat_a @ mat_b # 행렬 곱셈
# Out:
# tensor([[ 29, -16],
#         [ 38,   6]])
